# %% [markdown]
# # Meta Prompting: A Guide to Automated Prompt Optimization
#
# Welcome to our cookbook on meta prompting! In this guide, we'll explore how to take a basic prompt and refine it to enhance the quality of outputs from a language model. We'll use the example of summarizing news reports to illustrate the process.
#
#
# Meta-prompting is a technique where you use an LLM to generate or improve prompts. Typically this is done using a higher intelligence model that optimizes prompts for a model with less intelligence. It’s a process of using prompts to guide, structure, and optimize other prompts, helping ensure they’re more effective in guiding the LLM towards high-quality, relevant outputs. We'll be leveraging the capabilities of `o1-preview`, a more intelligent model with advanced reasoning skills, to improve a prompt for `gpt-4o`.
#
# We're committed to making your development journey with LLMs smoother and more accessible through this technique. Don't forget to check out our [Generate Anything](https://platform.openai.com/docs/guides/prompt-generation) feature in the playground — it's a fantastic starting point to dive into meta prompting.
#
# In this example, we'll begin with a simple prompt for summarizing news articles and then enhance it to see how the outputs improve. We'll use `o1-preview` to analyze and refine our prompt, adding more detail and clarity along the way. Finally, we'll evaluate the outputs systematically to understand the impact of our refinements.

# %%
import pandas as pd
import openai 
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
from pydantic import BaseModel
from datasets import load_dataset
from IPython.display import display, Markdown

client = openai.Client()

# %% [markdown]
# ## Importing the Data
#
# Let's kick things off by importing the `bbc_news_alltime` dataset from [HuggingFace](https://huggingface.co/datasets/RealTimeData/bbc_news_alltime). This dataset contains all BBC News articles, capturing everything published monthly from 2017 up to the latest complete month. For our experiment, we'll focus exclusively on a sample from a recent month—August 2024—to keep things current and manageable.

# %%
ds = load_dataset("RealTimeData/bbc_news_alltime", "2024-08")
df = pd.DataFrame(ds['train']).sample(n=100, random_state=1)
df.head()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#                                                   title published_date  \
# 2662  Laura Whitmore: I was gaslighted after raising...     2024-08-04
# 1865  Errollyn Wallen appointed as Master of the Kin...     2024-08-25
# 2554  SDLP: Matthew O'Toole endorses Claire Hanna fo...     2024-08-30
# 1338   Rotherham rioters among those jailed  - BBC News     2024-08-20
# 1232                             BBC News - BBC iPlayer     2024-08-02
#
#                                authors  \
# 2662  https://www.facebook.com/bbcnews
# 1865  https://www.facebook.com/bbcnews
# 2554  https://www.facebook.com/bbcnews
# 1338  https://www.facebook.com/bbcnews
# 1232                               NaN
#
#                                             description  \
# 2662  The former Love Island host said that things s...
# 1865  She is best known for her work on the 2012 Par...
# 2554  Matthew O'Toole had been named by some as a po...
# 1338  Two men who were part of a mob targeting a Hol...
# 1232                                                NaN
#
#                         section  \
# 2662                    Culture
# 1865                    Culture
# 2554  Northern Ireland Politics
# 1338            South Yorkshire
# 1232                        NaN
#
#                                                 content  \
# 2662  Television presenter Laura Whitmore has said t...
# 1865  Celebrated composer and singer-songwriter Erro...
# 2554  Matthew O'Toole leads his party's official opp...
# 1338  Rotherham pair among those jailed for UK rioti...
# 1232  JavaScript seems to be disabled. Please enable...
#
#                                                  link  \
# 2662  http://www.bbc.co.uk/news/articles/c9wvwvzm7x7o
# 1865  http://www.bbc.co.uk/news/articles/c4gl758g7zgo
# 2554  http://www.bbc.co.uk/news/articles/cvg41j7xrzdo
# 1338  http://www.bbc.co.uk/news/articles/cwywggd7qw6o
# 1232               http://www.bbc.co.uk/news/10318089
#
#                                               top_image
# 2662  https://ichef.bbci.co.uk/ace/standard/2560/cps...
# 1865  https://ichef.bbci.co.uk/ace/standard/2560/cps...
# 2554  https://ichef.bbci.co.uk/ace/standard/3840/cps...
# 1338  https://ichef.bbci.co.uk/ace/standard/2560/cps...
# 1232

# %% [markdown]
# ## Iterating on Prompts

# %% [markdown]
# Let's start with a straightforward prompt and then use `o1-preview` to enhance it for better results. We want to summarize news articles, so this is what i'll ask the model to do.

# %%
simple_prompt = "Summarize this news article: {article}"

# %% [markdown]
# To improve the prompt, we need to provide `o1-preview` with the context and goals we want to achieve. We can then ask it to generate a more detailed prompt that would produce richer and more comprehensive news summaries.

# %%
meta_prompt = """
Improve the following prompt to generate a more detailed summary. 
Adhere to prompt engineering best practices. 
Make sure the structure is clear and intuitive and contains the type of news, tags and sentiment analysis.

{simple_prompt}

Only return the prompt.
"""

# %%
def get_model_response(messages, model="o1-preview"):
    response = client.chat.completions.create(
        messages=messages,
        model=model,
    )
    return response.choices[0].message.content

messages = [{"role": "user", "content": meta_prompt.format(simple_prompt=simple_prompt)}]
complex_prompt = get_model_response(messages=messages, model="gpt-5.4-nano")
complex_prompt
# Out:
# 'Summarize the following news article in a detailed, structured format.\n\nARTICLE: {article}\n\nREQUIREMENTS (follow exactly):\n1. Provide a concise headline-style summary (1–2 sentences).\n2. Identify the type of news (e.g., Politics, Business, Tech, Finance, Sports, Health, Science, Entertainment, Legal, World).\n3. Extract the main topics as 5–10 bullet points (key events, facts, claims).\n4. Include relevant entities:\n   - People (if any)\n   - Organizations/companies\n   - Countries/regions\n5. Provide a “What’s new / Why it matters” section explaining significance in 2–4 sentences.\n6. Add a “Key data & quotes” section:\n   - List any important numbers, dates, statistics, or figures\n   - Include the most relevant short quote(s) if present (with attribution)\n7. Add “Tags”:\n   - Output 6–12 concise, normalized tags (single words or short phrases), e.g., “ceasefire”, “earnings”, “AI”, “regulation”, “inflation”, “election”\n8. Perform sentiment analysis (required):\n   - Sentiment label: choose one of [Positive, Negative, Neutral, Mixed]\n   - Sentiment score: integer from -5 (most negative) to +5 (most positive)\n   - Justification: 2–3 sentences referencing specific language or outcomes from the article\n9. Mention notable uncertainties/unknowns or what is not clarified in the article.\n10. End with a “Bottom line” section in 1–2 sentences.\n\nOUTPUT FORMAT (use these exact headings):\n- Headline Summary\n- News Type\n- Main Topics\n- Entities\n- What’s New / Why It Matters\n- Key Data & Quotes\n- Tags\n- Sentiment Analysis\n- Uncertainties / Open Questions\n- Bottom Line'

# %% [markdown]
# ## Generating the Summaries
#
# Now that we have both prompts, let's generate the summaries! For each entry in our dataset, we'll use both the simple and the enhanced prompts to see how they compare. By doing this, we'll get a firsthand look at how our refinements with `o1-preview` can lead to richer and more detailed summaries. Let's dive in and see the difference for ourselves!

# %%
def generate_response(prompt): 
    messages = [{"role": "user", "content": prompt}]
    response = get_model_response(messages, model="gpt-4o-mini")
    return response

def generate_summaries(row):
    simple_itinerary = generate_response(simple_prompt.format(article=row["content"]))
    complex_itinerary = generate_response(complex_prompt + row["content"])
    return simple_itinerary, complex_itinerary

# %% [markdown]
# Let's check if everything looks good and if we can generate a summary for the first news report.

# %%
simple_summary, complex_summary = generate_summaries(df.iloc[0])
print("SIMPLE:")
display(Markdown(simple_summary))
print("COMPLEX:")
display(Markdown(complex_summary))
# Out:
# SIMPLE:
# Television presenter Laura Whitmore has opened up about her experiences on Strictly Come Dancing, suggesting that challenges she faced during her time on the show eight years ago are now being acknowledged. In a recent interview, she described feeling "gaslit" and marginalized during her participation, and noted that many issues surrounding the treatment of women in the public eye are now being addressed more actively. Whitmore, who was eliminated in the seventh week of the 2016 season, reflected on how her portrayal on the show left her feeling "broken."
#
# She mentioned raising concerns about "inappropriate behavior" she experienced alongside others, and is providing evidence to support a BBC investigation into these claims. The controversy surrounding the show has escalated, with other celebrities, including Amanda Abbington and Zara McDermott, sharing similar allegations of mistreatment. The BBC has stated that it takes complaints seriously and is implementing new measures to enhance welfare and support for participants on the show, including the introduction of chaperones during rehearsals. Whitmore and dancer Giovanni Pernice, who has denied any abusive behavior, have not officially complained but are cooperating with the investigation and have stepped back from future participation in the series.
# COMPLEX:
# - **Headline Summary**
# Laura Whitmore reveals past struggles with mental health and accusations of being "gaslit" regarding her experiences on Strictly Come Dancing, amid rising allegations of inappropriate behavior on the show.
#
# - **News Type**
# Entertainment
#
# - **Main Topics**
#   - Laura Whitmore discusses her experiences from eight years ago on Strictly Come Dancing, mentioning feelings of being "gaslit."
#   - Allegations have surfaced regarding inappropriate behavior from celebrities, including Giovanni Pernice and Graziano Di Prima.
#   - Whitmore recalls being depicted negatively during her time on the show, describing a significant emotional impact.
#   - She has raised concerns about her treatment and has not formally complained but is providing evidence to support the BBC's investigation.
#   - The BBC is planning to implement new measures to improve participant welfare on the show.
#
# - **Entities**
#   - **People:** Laura Whitmore, Giovanni Pernice, Amanda Abbington, Zara McDermott, Graziano Di Prima
#   - **Organizations/companies:** BBC
#   - **Countries/regions:** United Kingdom
#
# - **What’s New / Why It Matters**
# This article highlights the ongoing discussion about mental health and accountability within the entertainment industry, focusing on the allegations of misconduct on a popular show. Whitmore's comments indicate a shift towards greater awareness and a willingness to address past mistreatment, reflecting broader societal changes in attitudes toward women's experiences and safety in public life.
#
# - **Key Data & Quotes**
#   - Whitmore mentioned feeling "broken" during her time on the show, indicating significant emotional distress.
#   - She stated, “I think we’re louder now, and we’re pulling people up on things now,” suggesting a movement toward greater transparency and advocacy for women's rights.
#   - Graziano Di Prima admitted to kicking Zara McDermott during rehearsal, highlighting the alleged inappropriate behavior.
#
# - **Tags**
#   - allegations
#   - misconduct
#   - mental health
#   - Strictly Come Dancing
#   - BBC
#   - accountability
#   - welfare
#   - gaslighting
#   - women's rights
#   - entertainment industry
#
# - **Sentiment Analysis**
#   - **Sentiment label:** Mixed
#   - **Sentiment score:** 2
#   - **Justification:** The article conveys both a sense of empowerment as women like Whitmore speak out against past injustices (positive) and the disturbing allegations surrounding the treatment of participants on the show (negative).
#
# - **Uncertainties / Open Questions**
# The article does not clarify specific identities of individuals involved in the allegations nor details about the ongoing investigations or potential outcomes. Whitmore's mention of unreported issues also leaves open questions about other participants' experiences.
#
# - **Bottom Line**
# Laura Whitmore's revelations regarding her time on Strictly Come Dancing bring to light significant concerns about the show's culture, urging greater accountability and support for participants amidst emerging allegations. The BBC’s commitment to enhancing welfare measures reflects an effort to address these critical issues.

# %% [markdown]
# By comparing the summaries generated from the simple and enhanced prompts, we can already see significant improvements. The initial summary gives us a general overview of the article, whereas the enhanced summary dives deeper — it not only provides a detailed summary but also categorizes the news type, lists relevant tags, and even includes a sentiment analysis.
#
# Let's test on the entire dataset now!

# %%
df = df.sample(n=5)

# Add new columns to the dataframe for storing itineraries
df['simple_summary'] = None
df['complex_summary'] = None

# Use ThreadPoolExecutor to generate itineraries concurrently
with ThreadPoolExecutor() as executor:
    futures = {executor.submit(generate_summaries, row): index for index, row in df.iterrows()}
    for future in tqdm(as_completed(futures), total=len(futures), desc="Generating Itineraries"):
        index = futures[future]
        simple_itinerary, complex_itinerary = future.result()
        df.at[index, 'simple_summary'] = simple_itinerary
        df.at[index, 'complex_summary'] = complex_itinerary

df.head()
# Out:
# Generating Itineraries: 100%|██████████| 5/5 [00:16<00:00,  3.26s/it]
#                                                   title published_date  \
# 945                  Newscast - 17/08/2024 - BBC Sounds     2024-08-17
# 1929  Root leads England to victory over Sri Lanka -...     2024-08-25
# 2270  Star Wars Outlaws: Massive defends glitches in...     2024-08-29
# 1696  Elsie Dot Stancombe's family call for celebrat...     2024-08-23
# 2654  Mercury retrograde: Does it really affect us? ...     2024-08-04
#
#                                authors  \
# 945                                NaN
# 1929                               NaN
# 2270  https://www.facebook.com/bbcnews
# 1696  https://www.facebook.com/bbcnews
# 2654  https://www.facebook.com/bbcnews
#
#                                             description    section  \
# 945   Adam Fleming and friends discuss the week's bi...        NaN
# 1929  Joe Root’s half-century helps England to defea...        NaN
# 2270  Creative director Julian Gerighty feels the ea...   Newsbeat
# 1696  Elsie Dot Stancombe's parents ask the communit...  Liverpool
# 2654  The Mercury retrograde phenomenon is associate...        NaN
#
#                                                 content  \
# 945   What Do The Riots Tell Us About The Far Right?...
# 1929  Joe Root’s half-century helps England to defea...
# 2270  Star Wars Outlaws has been troubled by early t...
# 1696  Help us to celebrate 'Elsie's special day' - f...
# 2654  'Blame all your problems on Mercury': What rea...
#
#                                                    link  \
# 945           http://www.bbc.co.uk/sounds/play/m00227v3
# 1929  http://www.bbc.co.uk/sport/cricket/videos/cn49...
# 2270    http://www.bbc.co.uk/news/articles/c9d1v41xzj5o
# 1696    http://www.bbc.co.uk/news/articles/c4glj41v30ro
# 2654    http://www.bbc.co.uk/news/articles/crg7yg4mknxo
#
#                                               top_image  \
# 945   https://ichef.bbci.co.uk/images/ic/320x320/p0j...
# 1929  https://ichef.bbci.co.uk/ace/standard/1024/cps...
# 2270  https://ichef.bbci.co.uk/ace/standard/976/cpsp...
# 1696  https://ichef.bbci.co.uk/ace/standard/3840/cps...
# 2654  https://ichef.bbci.co.uk/ace/standard/2048/cps...
#
#                                          simple_summary  \
# 945   The article explores the recent riots and thei...
# 1929  Joe Root's impressive half-century played a cr...
# 2270  "Star Wars Outlaws," the first-ever open-world...
# 1696  The family of seven-year-old Elsie Dot Stancom...
# 2654  The article discusses the phenomenon of Mercur...
#
#                                         complex_summary
# 945   - Headline Summary  \nAn investigation explore...
# 1929  - Headline Summary  \nJoe Root's half-century ...
# 2270  - **Headline Summary**  \nStar Wars Outlaws ex...
# 1696  - Headline Summary  \nCommunity mourns the ext...
# 2654  - **Headline Summary**  \nUnderstanding Mercur...

# %% [markdown]
# ## Evaluating the Results
#
# To assess the difference in performance between the two prompts, we'll use a structured evaluation approach with the LLM acting as a judge. This means we'll leverage the language model itself to evaluate and compare the outputs based on specific criteria.
#
# **What Does "LLM as a Judge" Mean?**
#
# Using an LLM as a judge involves having the language model evaluate its own outputs or those of another model. It applies predefined criteria to assess aspects like accuracy, clarity, and relevance. This approach helps us obtain an objective and consistent evaluation without human bias, making it easier to identify improvements between different prompts. Our cookbook on [Getting Started with OpenAI Evals](https://cookbook.openai.com/examples/evaluation/getting_started_with_openai_evals) offers a glimps on how you can get started with this approach.
#
#
# Here's the prompt we'll use for evaluation:

# %%
evaluation_prompt = """
You are an expert editor tasked with evaluating the quality of a news article summary. Below is the original article and the summary to be evaluated:

**Original Article**:  
{original_article}

**Summary**:  
{summary}

Please evaluate the summary based on the following criteria, using a scale of 1 to 5 (1 being the lowest and 5 being the highest). Be critical in your evaluation and only give high scores for exceptional summaries:

1. **Categorization and Context**: Does the summary clearly identify the type or category of news (e.g., Politics, Technology, Sports) and provide appropriate context?  
2. **Keyword and Tag Extraction**: Does the summary include relevant keywords or tags that accurately capture the main topics and themes of the article?  
3. **Sentiment Analysis**: Does the summary accurately identify the overall sentiment of the article and provide a clear, well-supported explanation for this sentiment?  
4. **Clarity and Structure**: Is the summary clear, well-organized, and structured in a way that makes it easy to understand the main points?  
5. **Detail and Completeness**: Does the summary provide a detailed account that includes all necessary components (type of news, tags, sentiment) comprehensively?  


Provide your scores and justifications for each criterion, ensuring a rigorous and detailed evaluation.
"""

class ScoreCard(BaseModel):
    justification: str
    categorization: int
    keyword_extraction: int
    sentiment_analysis: int
    clarity_structure: int
    detail_completeness: int

# %% [markdown]
# Here's a pro tip — you can actually use meta prompting to refine your evaluation prompt as well! By applying the same iterative enhancement to the prompt that instructs the LLM to act as a judge, you can make your evaluations even more precise and insightful.
#
# Let's use this prompt to evaluate our summaries!

# %%
def evaluate_summaries(row):
    simple_messages = [{"role": "user", "content": evaluation_prompt.format(original_article=row["content"], summary=row['simple_summary'])}]
    complex_messages = [{"role": "user", "content": evaluation_prompt.format(original_article=row["content"], summary=row['complex_summary'])}]
    
    simple_summary = client.beta.chat.completions.parse(
        model="gpt-4o",
        messages=simple_messages,
        response_format=ScoreCard)
    simple_summary = simple_summary.choices[0].message.parsed
    
    complex_summary = client.beta.chat.completions.parse(
        model="gpt-4o",
        messages=complex_messages,
        response_format=ScoreCard)
    complex_summary = complex_summary.choices[0].message.parsed
    
    return simple_summary, complex_summary

# Add new columns to the dataframe for storing evaluations
df['simple_evaluation'] = None
df['complex_evaluation'] = None

# Use ThreadPoolExecutor to evaluate itineraries concurrently
with ThreadPoolExecutor() as executor:
    futures = {executor.submit(evaluate_summaries, row): index for index, row in df.iterrows()}
    for future in tqdm(as_completed(futures), total=len(futures), desc="Evaluating Summaries"):
        index = futures[future]
        simple_evaluation, complex_evaluation = future.result()
        df.at[index, 'simple_evaluation'] = simple_evaluation
        df.at[index, 'complex_evaluation'] = complex_evaluation

df.head()
# Out:
# Evaluating Summaries: 100%|██████████| 5/5 [00:13<00:00,  2.76s/it]
#                                                   title published_date  \
# 945                  Newscast - 17/08/2024 - BBC Sounds     2024-08-17
# 1929  Root leads England to victory over Sri Lanka -...     2024-08-25
# 2270  Star Wars Outlaws: Massive defends glitches in...     2024-08-29
# 1696  Elsie Dot Stancombe's family call for celebrat...     2024-08-23
# 2654  Mercury retrograde: Does it really affect us? ...     2024-08-04
#
#                                authors  \
# 945                                NaN
# 1929                               NaN
# 2270  https://www.facebook.com/bbcnews
# 1696  https://www.facebook.com/bbcnews
# 2654  https://www.facebook.com/bbcnews
#
#                                             description    section  \
# 945   Adam Fleming and friends discuss the week's bi...        NaN
# 1929  Joe Root’s half-century helps England to defea...        NaN
# 2270  Creative director Julian Gerighty feels the ea...   Newsbeat
# 1696  Elsie Dot Stancombe's parents ask the communit...  Liverpool
# 2654  The Mercury retrograde phenomenon is associate...        NaN
#
#                                                 content  \
# 945   What Do The Riots Tell Us About The Far Right?...
# 1929  Joe Root’s half-century helps England to defea...
# 2270  Star Wars Outlaws has been troubled by early t...
# 1696  Help us to celebrate 'Elsie's special day' - f...
# 2654  'Blame all your problems on Mercury': What rea...
#
#                                                    link  \
# 945           http://www.bbc.co.uk/sounds/play/m00227v3
# 1929  http://www.bbc.co.uk/sport/cricket/videos/cn49...
# 2270    http://www.bbc.co.uk/news/articles/c9d1v41xzj5o
# 1696    http://www.bbc.co.uk/news/articles/c4glj41v30ro
# 2654    http://www.bbc.co.uk/news/articles/crg7yg4mknxo
#
#                                               top_image  \
# 945   https://ichef.bbci.co.uk/images/ic/320x320/p0j...
# 1929  https://ichef.bbci.co.uk/ace/standard/1024/cps...
# 2270  https://ichef.bbci.co.uk/ace/standard/976/cpsp...
# 1696  https://ichef.bbci.co.uk/ace/standard/3840/cps...
# 2654  https://ichef.bbci.co.uk/ace/standard/2048/cps...
#
#                                          simple_summary  \
# 945   The article explores the recent riots and thei...
# 1929  Joe Root's impressive half-century played a cr...
# 2270  "Star Wars Outlaws," the first-ever open-world...
# 1696  The family of seven-year-old Elsie Dot Stancom...
# 2654  The article discusses the phenomenon of Mercur...
#
#                                         complex_summary  \
# 945   - Headline Summary  \nAn investigation explore...
# 1929  - Headline Summary  \nJoe Root's half-century ...
# 2270  - **Headline Summary**  \nStar Wars Outlaws ex...
# 1696  - Headline Summary  \nCommunity mourns the ext...
# 2654  - **Headline Summary**  \nUnderstanding Mercur...
#
#                                       simple_evaluation  \
# 945   justification='1. **Categorization and Context...
# 1929  justification='**Categorization and Context (5...
# 2270  justification='The summary effectively identif...
# 1696  justification='1. **Categorization and Context...
# 2654  justification='The summary aligns with the cat...
#
#                                      complex_evaluation
# 945   justification="1. **Categorization and Context...
# 1929  justification='1. **Categorization and Context...
# 2270  justification="The summary clearly identifies ...
# 1696  justification='### Evaluation of News Article ...
# 2654  justification='The summary offers a clear cate...

# %%
import matplotlib.pyplot as plt

df["simple_scores"] = df["simple_evaluation"].apply(lambda x: [score for key, score in x.model_dump().items() if key != 'justification'])
df["complex_scores"] = df["complex_evaluation"].apply(lambda x: [score for key, score in x.model_dump().items() if key != 'justification'])


# Calculate average scores for each criterion
criteria = [
    'Categorisation',
    'Keywords and Tags',
    'Sentiment Analysis',
    'Clarity and Structure',
    'Detail and Completeness'
]

# Calculate average scores for each criterion by model
simple_avg_scores = df['simple_scores'].apply(pd.Series).mean()
complex_avg_scores = df['complex_scores'].apply(pd.Series).mean()


# Prepare data for plotting
avg_scores_df = pd.DataFrame({
    'Criteria': criteria,
    'Original Prompt': simple_avg_scores,
    'Improved Prompt': complex_avg_scores
})

# Plotting
ax = avg_scores_df.plot(x='Criteria', kind='bar', figsize=(6, 4))
plt.ylabel('Average Score')
plt.title('Comparison of Simple vs Complex Prompt Performance by Model')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# After evaluating the results, we found that while the basic prompt performed well in clarity and structure, the enhanced prompt significantly improved outputs across several other key criteria: Categorization, Keywords and Tags, Sentiment Analysis, and Detail and Completeness. The complex prompt led to summaries that were more informative, better organized, and richer in content.
#
# This demonstrates how refining prompts can greatly enhance the quality of the generated summaries. Although this is a simplified example, the benefits of prompt optimization are expected to be even more pronounced in real-world, production-level applications, leading to outputs that are more aligned with specific goals and user needs.

# %% [markdown]
# ## Conclusion
#
# Meta prompting is a powerful technique that can significantly enhance the quality of outputs from language models. Our exploration showed that starting with a simple prompt and refining it using `o1-preview` led to summaries that were more informative, better organized, and richer in content—improving across key criteria like categorization, keywords and tags, sentiment analysis, and completeness. This exercise underscores the value of prompt optimization, and even in this simplified example, the benefits are clear. In real-world applications, leveraging meta prompting and tools like `o1-preview` can elevate language model performance to better meet your specific goals and user needs.
